# %%
git config pull.rebase false
# Out:
#   Cell In[2], line 1
#     git config pull.rebase false
#         ^
# SyntaxError: invalid syntax

# %%
import pygame
import random

pygame.init()

WINDOW_WIDTH = 800
WINDOW_HEIGHT = 800
window = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
pygame.display.set_caption("Intersection Simulation")

BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0, 100)
GREEN = (0, 255, 0, 100)
YELLOW = (255, 255, 0, 100)
GRAY = (60, 60, 60)

ambient_1 = pygame.image.load('assets/img/ambient_1.png')
ambient_2 = pygame.image.load('assets/img/ambient_2.png')
ambient_3 = pygame.image.load('assets/img/ambient_3.png')
ambient_4 = pygame.image.load('assets/img/ambient_4.png')

try:
    pygame.mixer.init()
    # Set audio effect in loop
    pygame.mixer.music.load('assets/audio/Street Sound Effect.mp3')
    pygame.mixer.music.play(-1)
except pygame.error as e:
    print(f"Warning: {e}")

# Load image, resize it to be 370x370 and put it in the right corner
ambient_1 = pygame.transform.scale(ambient_1, (WINDOW_WIDTH//2 - 30, WINDOW_HEIGHT//2 - 30))
ambient_2 = pygame.transform.scale(ambient_2, (WINDOW_WIDTH//2 - 30, WINDOW_HEIGHT//2 - 30))
ambient_3 = pygame.transform.scale(ambient_3, (WINDOW_WIDTH//2 - 30, WINDOW_HEIGHT//2 - 30))
ambient_4 = pygame.transform.scale(ambient_4, (WINDOW_WIDTH//2 - 30, WINDOW_HEIGHT//2 - 30))
window.blit(ambient_1, (0, 0))
window.blit(ambient_2, (WINDOW_WIDTH//2 + 30, 0))
window.blit(ambient_3, (WINDOW_WIDTH//2 + 30, WINDOW_HEIGHT//2 + 30))
window.blit(ambient_4, (0, WINDOW_HEIGHT//2 + 30))

class Car:
    def __init__(self, x, y, direction):
        self.x = x
        self.y = y
        self.direction = direction
        self.speed = 2
        self.width = 20
        self.length = 40
        self.stopped = False
        self.color = (random.randint(1, 255), random.randint(1, 255), random.randint(1, 255))
        self.turn_right = False#random.choice([False, True])
        self.waiting_time = 0

    def move(self):
        if not self.stopped:
            if self.direction == 'up':
                self.y -= self.speed
            elif self.direction == 'down':
                self.y += self.speed
            elif self.direction == 'left':
                self.x -= self.speed
            elif self.direction == 'right':
                self.x += self.speed

    def draw(self, win, pygame):
        if self.direction == 'up':
            pygame.draw.rect(win, self.color, (self.x, self.y, self.width, self.length))
            # Check if car wants to turn, if so add a blinking turn signal
            if self.turn_right == True and pygame.time.get_ticks()//1000 % 2 == 0:
                pygame.draw.polygon(win, (255, 85, 0), [(self.x + 20, self.y), (self.x + 20, self.y + 10), (self.x + 25, self.y - 5), (self.x + 25, self.y + 15)])
            # Add waiting_time text to the car that moves with it
            font = pygame.font.Font(None, 20)
            text = font.render(str(self.waiting_time//30), True, (255, 255, 255))
            text = pygame.transform.rotate(text, 90)
            win.blit(text, (self.x + 5, self.y + 5))
        elif self.direction == 'down':
            pygame.draw.rect(win, self.color, (self.x, self.y, self.width, self.length))
            # Check if car wants to turn, if so add a blinking turn signal
            if self.turn_right == True and pygame.time.get_ticks()//1000 % 2 == 0:
                pygame.draw.polygon(win, (255, 85, 0), [(self.x, self.y + 40), (self.x, self.y + 30), (self.x - 5, self.y + 45), (self.x - 5, self.y + 25)])
            # Add waiting_time text to the car that moves with it
            font = pygame.font.Font(None, 20)
            text = font.render(str(self.waiting_time//30), True, (255, 255, 255))
            text = pygame.transform.rotate(text, 90)
            win.blit(text, (self.x + 5, self.y + 5))
        elif self.direction == 'left':
            pygame.draw.rect(win, self.color, (self.x, self.y, self.length, self.width))
            # Check if car wants to turn, if so add a blinking turn signal
            if self.turn_right == True and pygame.time.get_ticks()//1000 % 2 == 0:
                pygame.draw.polygon(win, (255, 85, 0), [(self.x, self.y), (self.x + 10, self.y), (self.x - 5, self.y - 5), (self.x + 15, self.y - 5)])
            # Add waiting_time text to the car that moves with it
            font = pygame.font.Font(None, 20)
            text = font.render(str(self.waiting_time//30), True, (255, 255, 255))
            win.blit(text, (self.x + 5, self.y + 5))
        else:
            pygame.draw.rect(win, self.color, (self.x, self.y, self.length, self.width))
            # Check if car wants to turn, if so add a blinking turn signal
            if self.turn_right == True and pygame.time.get_ticks()//1000 % 2 == 0:
                pygame.draw.polygon(win, (255, 85, 0), [(self.x + 40, self.y + 20), (self.x + 30, self.y + 20), (self.x + 45, self.y + 25), (self.x + 25, self.y + 25)])
            # Add waiting_time text to the car that moves with it
            font = pygame.font.Font(None, 20)
            text = font.render(str(self.waiting_time//30), True, (255, 255, 255))
            win.blit(text, (self.x + 5, self.y + 5))

    def stop(self):
        self.stopped = True

    def can_move(self, other_cars):
        for other_car in other_cars:
            if other_car.stopped:
                if self.direction == other_car.direction == 'up':
                    if other_car.y + other_car.length + 4 <= self.y <= other_car.y + other_car.length + 6:
                        return False
                elif self.direction == other_car.direction == 'down':
                    if other_car.y - self.length - 6 <= self.y <= other_car.y - self.length - 4:
                        return False
                elif self.direction == other_car.direction == 'left':
                    if other_car.x + other_car.length + 4 <= self.x <= other_car.x + other_car.length + 6:
                        return False
                elif self.direction == other_car.direction == 'right':
                    if other_car.x - self.length - 6 <= self.x <= other_car.x - self.length - 4:
                        return False
        return True

    def turn_or_straight(self):
        if self.turn_right == True:
            if self.direction == 'up' and self.y <= WINDOW_HEIGHT//2:
                self.direction = 'right'
                self.x += self.length // 2
                self.y = WINDOW_HEIGHT//2 + 5
                self.turn_right = False
            elif self.direction == 'down' and self.y + self.length >= WINDOW_HEIGHT//2:
                self.direction = 'left'
                self.x -= self.length // 2
                self.y = WINDOW_HEIGHT//2 - 20 - 4
                self.turn_right = False
            elif self.direction == 'left' and self.x <= WINDOW_WIDTH//2:
                self.direction = 'up'
                self.x = WINDOW_WIDTH//2 + 5
                self.y -= self.length // 2
                self.turn_right = False
            elif self.direction == 'right' and self.x + self.length >= WINDOW_WIDTH//2:
                self.direction = 'down'
                self.x = WINDOW_WIDTH//2 - 20 - 4
                self.y += self.length // 2
                self.turn_right = False

class Stoplight:
    def __init__(self, color):
        self.color_NS = color
        if self.color_NS == GREEN:
            self.color_EW = RED
        else:
            self.color_EW = GREEN
        self.time_yellow = 0
        self.time_green = 0

    def switch_yellow(self):
        if self.color_NS == GREEN:
            self.color_NS = YELLOW
        elif self.color_EW == GREEN:
            self.color_EW = YELLOW

    def update_stoplight(self):
        if self.color_NS == GREEN or self.color_EW == GREEN:
            self.time_green += 1
        if self.color_NS == YELLOW or self.color_EW == YELLOW:
            self.time_yellow += 1

        if self.time_yellow >= 90:
            if self.color_NS == YELLOW:
                self.color_NS = RED
                self.color_EW = GREEN
                self.time_green = 0
            elif self.color_EW == YELLOW:
                self.color_EW = RED
                self.color_NS = GREEN
                self.time_green = 0
            self.time_yellow = 0


class TrafficMDP:
    def __init__(self, discount_factor=0.95, theta=0.01):
        self.states = ['EW', 'NS']
        self.actions = ['maintain', 'change']
        self.current_state = None
        self.discount_factor = discount_factor
        self.theta = theta
        self.values = {state: 0 for state in self.states}
        self.policy = {'maintain': 0.5, 'change': 0.5}

    def get_reward(self, cars, action):
        if self.current_state == 'EW':
            stopped_cars = [car for car in cars if car.direction in ['up', 'down'] and car.stopped]
            moving_cars = [car for car in cars if car.direction in ['left', 'right'] and not car.stopped]
        else:
            stopped_cars = [car for car in cars if (car.direction in ['left', 'right']) and car.stopped]
            moving_cars = [car for car in cars if (car.direction in ['up', 'down']) and not car.stopped]
        
        avg_wait_time = sum(car.waiting_time for car in stopped_cars) / len(stopped_cars) if stopped_cars else 0
        num_moving_cars = len(moving_cars)
        
        if action == 'change':
            return avg_wait_time / num_moving_cars if num_moving_cars > 0 else avg_wait_time
        else:
            return num_moving_cars / avg_wait_time if avg_wait_time > 0 else num_moving_cars

    def policy_evaluation(self, cars):
        i = 0
        while True:
            delta = 0
            for state in self.states:
                v = self.values[state]
                
                maintain_reward = self.get_reward(cars, 'maintain')
                change_reward = self.get_reward(cars, 'change')
                
                next_state = 'NS' if state == 'EW' else 'EW'
                
                maintain_value = maintain_reward + self.discount_factor * self.values[state]
                change_value = change_reward + self.discount_factor * self.values[next_state]
                
                self.values[state] = (
                    self.policy['maintain'] * maintain_value +
                    self.policy['change'] * change_value
                )
                
                delta = max(delta, abs(v - self.values[state]))

            i += 1
            
            if round(delta, 2) <= self.theta or i == 100:
                return
            else:
                print('not done, delta: ', round(delta, 2), ', i: ', i)

    def policy_improvement(self):
        policy_stable = True
        for state in self.states:
            old_action = max(self.policy, key=self.policy.get)
            next_state = 'NS' if state == 'EW' else 'EW'
            action_values = {
                'maintain': self.values[state],
                'change': self.values[next_state]
            }
            best_action = max(action_values, key=action_values.get)
            self.policy = {'maintain': 0.9, 'change': 0.1} if best_action == 'maintain' else {'maintain': 0.1, 'change': 0.9}
            if old_action != best_action:
                policy_stable = False
        return policy_stable


    def policy_iteration(self, current_state, cars):
        self.current_state = current_state
        i = 0
        while True:
            self.policy_evaluation(cars)
            i += 1
            if self.policy_improvement() or i == 100:
                print('Policy: ', self.policy)
                return

    def get_action(self):
        return random.choices(self.actions, weights=[self.policy['maintain'], self.policy['change']])[0]

        
def main():
    run = True
    clock = pygame.time.Clock()

    cars = []
    prev_time = 0
    stoplight = Stoplight(random.choice([GREEN, RED]))
    mdp = TrafficMDP()
    frame_count = 0
    seconds_elapsed = 0

    while run:
        clock.tick(30)
        stoplight.update_stoplight()
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                run = False
        time = pygame.time.get_ticks() // 1000
        if time != prev_time:
            if time % 3 == 0:
                direction = random.choice(['up', 'down'])
                if direction == 'up':
                    cars.append(Car(WINDOW_WIDTH//2 + 5, WINDOW_HEIGHT, direction))
                elif direction == 'down':
                    cars.append(Car(WINDOW_WIDTH//2 - 20 - 4, 0, direction))
                elif direction == 'left':
                    cars.append(Car(WINDOW_WIDTH, WINDOW_HEIGHT//2 - 20 - 4, direction))
                elif direction == 'right':
                    cars.append(Car(0, WINDOW_HEIGHT//2 + 5, direction))
            prev_time = time
        
        frame_count += 1
        seconds_elapsed = frame_count // 30

        if (stoplight.color_NS == GREEN or stoplight.color_EW == GREEN) and seconds_elapsed >= 10:
            current_state = 'NS' if stoplight.color_NS == GREEN else 'EW'
            mdp.policy_iteration(current_state, cars)
            action = mdp.get_action()
            if action == 'change':
                stoplight.switch_yellow()
                seconds_elapsed = 0
                frame_count = 0

        for car in cars:
            if not car.stopped:
                if ((car.direction == 'up' and car.y == WINDOW_HEIGHT//2 + 50 and (stoplight.color_NS == RED or stoplight.color_NS == YELLOW)) or
                    (car.direction == 'down' and car.y + car.length == WINDOW_HEIGHT//2 - 50 and (stoplight.color_NS == RED or stoplight.color_NS == YELLOW)) or
                    (car.direction == 'left' and car.x == WINDOW_WIDTH//2 + 50 and (stoplight.color_EW == RED or stoplight.color_EW == YELLOW)) or
                    (car.direction == 'right' and car.x + car.length == WINDOW_WIDTH//2 - 50 and (stoplight.color_EW == RED or stoplight.color_EW == YELLOW))) or not car.can_move(cars):
                    car.stop()
                else:
                    if ((car.direction == 'up' and car.y <= WINDOW_HEIGHT//2 + car.speed and car.y >= WINDOW_HEIGHT//2 - car.speed) or
                        (car.direction == 'down' and car.y + car.length >= WINDOW_HEIGHT//2 - car.speed and car.y + car.length <= WINDOW_HEIGHT//2 + car.speed) or
                        (car.direction == 'left' and car.x <= WINDOW_WIDTH//2 + car.speed and car.x >= WINDOW_WIDTH//2 - car.speed) or
                        (car.direction == 'right' and car.x + car.length >= WINDOW_WIDTH//2 - car.speed and car.x + car.length <= WINDOW_WIDTH//2 + car.speed)):
                        car.turn_or_straight()
                    car.move()
            elif car.stopped and ((car.direction in ['up', 'down'] and stoplight.color_NS == GREEN) or (car.direction in ['left', 'right'] and stoplight.color_EW == GREEN)):
                car.stopped = False
                car.move()
            if car.stopped:
                car.waiting_time += 1
            else:
                car.waiting_time = 0

        cars = [car for car in cars if 0 <= car.x <= WINDOW_WIDTH and 0 <= car.y <= WINDOW_HEIGHT]

        # Draw intersection
        ## Draw road
        pygame.draw.line(window, GRAY, (0, WINDOW_HEIGHT//2), (WINDOW_WIDTH, WINDOW_HEIGHT//2), 60)
        pygame.draw.line(window, GRAY, (WINDOW_WIDTH//2, 0), (WINDOW_WIDTH//2, WINDOW_HEIGHT), 60)
        ## Draw lanes
        pygame.draw.line(window, WHITE, (0, WINDOW_HEIGHT//2 - 28), (WINDOW_WIDTH, WINDOW_HEIGHT//2 - 28), 1)
        pygame.draw.line(window, WHITE, (0, WINDOW_HEIGHT//2 + 28), (WINDOW_WIDTH, WINDOW_HEIGHT//2 + 28), 1)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 28, 0), (WINDOW_WIDTH//2 - 28, WINDOW_HEIGHT), 1)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 28, 0), (WINDOW_WIDTH//2 + 28, WINDOW_HEIGHT), 1)
        pygame.draw.line(window, WHITE, (0, WINDOW_HEIGHT//2), (WINDOW_WIDTH, WINDOW_HEIGHT//2), 4)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2, 0), (WINDOW_WIDTH//2, WINDOW_HEIGHT), 4)
        ## Draw crosswalks
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 23, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 - 23, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 17, WINDOW_HEIGHT//2 -200), (WINDOW_WIDTH//2 - 17, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 12, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 - 12, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 6, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 - 6, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 6, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 + 6, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 12, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 + 12, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 17, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 + 17, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 23, WINDOW_HEIGHT//2 - 200), (WINDOW_WIDTH//2 + 23, WINDOW_HEIGHT//2 - 180), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 - 23), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 - 23), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 - 17), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 - 17), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 - 12), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 - 12), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 - 6), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 - 6), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 + 6), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 + 6), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 + 12), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 + 12), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 + 17), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 + 17), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 200, WINDOW_HEIGHT//2 + 23), (WINDOW_WIDTH//2 - 180, WINDOW_HEIGHT//2 + 23), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 - 23), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 - 23), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 - 17), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 - 17), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 - 12), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 - 12), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 - 6), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 - 6), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 + 6), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 + 6), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 + 12), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 + 12), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 + 17), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 + 17), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 180, WINDOW_HEIGHT//2 + 23), (WINDOW_WIDTH//2 + 200, WINDOW_HEIGHT//2 + 23), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 23, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 - 23, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 17, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 - 17, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 12, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 - 12, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 - 6, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 - 6, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 6, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 + 6, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 12, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 + 12, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 17, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 + 17, WINDOW_HEIGHT//2 + 220), 2)
        pygame.draw.line(window, WHITE, (WINDOW_WIDTH//2 + 23, WINDOW_HEIGHT//2 + 200), (WINDOW_WIDTH//2 + 23, WINDOW_HEIGHT//2 + 220), 2)
        ## Cover intersection
        pygame.draw.rect(window, GRAY, (WINDOW_WIDTH//2 - 29, WINDOW_HEIGHT//2 - 29, 60, 60))
        ## Draw stoplights as stop lines
        pygame.draw.line(window, stoplight.color_NS, (WINDOW_WIDTH//2 - 27, WINDOW_HEIGHT//2 - 32), (WINDOW_WIDTH//2 - 2, WINDOW_HEIGHT//2 - 32), 5)
        pygame.draw.line(window, stoplight.color_NS, (WINDOW_WIDTH//2 + 3, WINDOW_HEIGHT//2 + 33), (WINDOW_WIDTH//2 + 27, WINDOW_HEIGHT//2 + 33), 5)
        pygame.draw.line(window, stoplight.color_EW, (WINDOW_WIDTH//2 - 32, WINDOW_HEIGHT//2 + 3), (WINDOW_WIDTH//2 - 32, WINDOW_HEIGHT//2 + 27), 5)
        pygame.draw.line(window, stoplight.color_EW, (WINDOW_WIDTH//2 + 33, WINDOW_HEIGHT//2 - 27), (WINDOW_WIDTH//2 + 33, WINDOW_HEIGHT//2 - 2), 5)
        
        # Draw cars
        for car in cars:
            car.draw(window, pygame)
        
        pygame.display.update()

    pygame.quit()

if __name__ == "__main__":
    main()
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# pygame 2.5.2 (SDL 2.30.5, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# not done, delta:  64.16 , i:  1
# not done, delta:  54.77 , i:  2
# not done, delta:  50.31 , i:  3
# not done, delta:  47.6 , i:  4
# not done, delta:  44.61 , i:  5
# not done, delta:  41.71 , i:  6
# not done, delta:  38.97 , i:  7
# not done, delta:  36.4 , i:  8
# not done, delta:  34.0 , i:  9
# not done, delta:  31.76 , i:  10
# not done, delta:  29.67 , i:  11
# not done, delta:  27.71 , i:  12
# not done, delta:  25.88 , i:  13
# not done, delta:  24.18 , i:  14
# not done, delta:  22.58 , i:  15
# not done, delta:  21.09 , i:  16
# not done, delta:  19.7 , i:  17
# not done, delta:  18.4 , i:  18
# not done, delta:  17.19 , i:  19
# not done, delta:  16.06 , i:  20
# not done, delta:  15.0 , i:  21
# not done, delta:  14.01 , i:  22
# not done, delta:  13.09 , i:  23
# not done, delta:  12.22 , i:  24
# not done, delta:  11.42 , i:  25
# not done, delta:  10.67 , i:  26
# not done, delta:  9.96 , i:  27
# not done, delta:  9.31 , i:  28
# not done, delta:  8.69 , i:  29
# not done, delta:  8.12 , i:  30
# not done, delta:  7.58 , i:  31
# not done, delta:  7.08 , i:  32
# not done, delta:  6.62 , i:  33
# not done, delta:  6.18 , i:  34
# not done, delta:  5.77 , i:  35
# not done, delta:  5.39 , i:  36
# not done, delta:  5.04 , i:  37
# not done, delta:  4.71 , i:  38
# not done, delta:  4.4 , i:  39
# not done, delta:  4.11 , i:  40
# not done, delta:  3.83 , i:  41
# not done, delta:  3.58 , i:  42
# not done, delta:  3.35 , i:  43
# not done, delta:  3.13 , i:  44
# not done, delta:  2.92 , i:  45
# not done, delta:  2.73 , i:  46
# not done, delta:  2.55 , i:  47
# not done, delta:  2.38 , i:  48
# not done, delta:  2.22 , i:  49
# not done, delta:  2.08 , i:  50
# not done, delta:  1.94 , i:  51
# not done, delta:  1.81 , i:  52
# not done, delta:  1.69 , i:  53
# not done, delta:  1.58 , i:  54
# not done, delta:  1.48 , i:  55
# not done, delta:  1.38 , i:  56
# not done, delta:  1.29 , i:  57
# not done, delta:  1.2 , i:  58
# not done, delta:  1.12 , i:  59
# not done, delta:  1.05 , i:  60
# not done, delta:  0.98 , i:  61
# not done, delta:  0.92 , i:  62
# not done, delta:  0.86 , i:  63
# not done, delta:  0.8 , i:  64
# not done, delta:  0.75 , i:  65
# not done, delta:  0.7 , i:  66
# not done, delta:  0.65 , i:  67
# not done, delta:  0.61 , i:  68
# not done, delta:  0.57 , i:  69
# not done, delta:  0.53 , i:  70
# not done, delta:  0.5 , i:  71
# not done, delta:  0.46 , i:  72
# not done, delta:  0.43 , i:  73
# not done, delta:  0.4 , i:  74
# not done, delta:  0.38 , i:  75
# not done, delta:  0.35 , i:  76
# not done, delta:  0.33 , i:  77
# not done, delta:  0.31 , i:  78
# not done, delta:  0.29 , i:  79
# not done, delta:  0.27 , i:  80
# not done, delta:  0.25 , i:  81
# not done, delta:  0.23 , i:  82
# not done, delta:  0.22 , i:  83
# not done, delta:  0.2 , i:  84
# not done, delta:  0.19 , i:  85
# not done, delta:  0.18 , i:  86
# not done, delta:  0.17 , i:  87
# not done, delta:  0.16 , i:  88
# not done, delta:  0.15 , i:  89
# not done, delta:  0.14 , i:  90
# not done, delta:  0.13 , i:  91
# not done, delta:  0.12 , i:  92
# not done, delta:  0.11 , i:  93
# not done, delta:  0.1 , i:  94
# not done, delta:  0.1 , i:  95
# not done, delta:  0.09 , i:  96
# not done, delta:  0.08 , i:  97
# not done, delta:  0.08 , i:  98
# not done, delta:  0.07 , i:  99
# not done, delta:  38.06 , i:  1
# not done, delta:  35.7 , i:  2
# not done, delta:  33.56 , i:  3
# not done, delta:  31.58 , i:  4
# not done, delta:  29.76 , i:  5
# not done, delta:  28.07 , i:  6
# not done, delta:  26.5 , i:  7
# not done, delta:  25.04 , i:  8
# not done, delta:  23.76 , i:  9
# not done, delta:  22.57 , i:  10
# not done, delta:  21.42 , i:  11
# not done, delta:  20.32 , i:  12
# not done, delta:  19.28 , i:  13
# not done, delta:  18.29 , i:  14
# not done, delta:  17.34 , i:  15
# not done, delta:  16.44 , i:  16
# not done, delta:  15.58 , i:  17
# not done, delta:  14.77 , i:  18
# not done, delta:  14.0 , i:  19
# not done, delta:  13.27 , i:  20
# not done, delta:  12.57 , i:  21
# not done, delta:  11.92 , i:  22
# not done, delta:  11.29 , i:  23
# not done, delta:  10.7 , i:  24
# not done, delta:  10.14 , i:  25
# not done, delta:  9.61 , i:  26
# not done, delta:  9.1 , i:  27
# not done, delta:  8.63 , i:  28
# not done, delta:  8.17 , i:  29
# not done, delta:  7.74 , i:  30
# not done, delta:  7.34 , i:  31
# not done, delta:  6.95 , i:  32
# not done, delta:  6.59 , i:  33
# not done, delta:  6.24 , i:  34
# not done, delta:  5.91 , i:  35
# not done, delta:  5.6 , i:  36
# not done, delta:  5.31 , i:  37
# not done, delta:  5.03 , i:  38
# not done, delta:  4.77 , i:  39
# not done, delta:  4.52 , i:  40
# not done, delta:  4.28 , i:  41
# not done, delta:  4.05 , i:  42
# not done, delta:  3.84 , i:  43
# not done, delta:  3.64 , i:  44
# not done, delta:  3.45 , i:  45
# not done, delta:  3.27 , i:  46
# not done, delta:  3.09 , i:  47
# not done, delta:  2.93 , i:  48
# not done, delta:  2.78 , i:  49
# not done, delta:  2.63 , i:  50
# not done, delta:  2.49 , i:  51
# not done, delta:  2.36 , i:  52
# not done, delta:  2.24 , i:  53
# not done, delta:  2.12 , i:  54
# not done, delta:  2.01 , i:  55
# not done, delta:  1.9 , i:  56
# not done, delta:  1.8 , i:  57
# not done, delta:  1.71 , i:  58
# not done, delta:  1.62 , i:  59
# not done, delta:  1.53 , i:  60
# not done, delta:  1.45 , i:  61
# not done, delta:  1.38 , i:  62
# not done, delta:  1.31 , i:  63
# not done, delta:  1.24 , i:  64
# not done, delta:  1.17 , i:  65
# not done, delta:  1.11 , i:  66
# not done, delta:  1.05 , i:  67
# not done, delta:  1.0 , i:  68
# not done, delta:  0.94 , i:  69
# not done, delta:  0.89 , i:  70
# not done, delta:  0.85 , i:  71
# not done, delta:  0.8 , i:  72
# not done, delta:  0.76 , i:  73
# not done, delta:  0.72 , i:  74
# not done, delta:  0.68 , i:  75
# not done, delta:  0.65 , i:  76
# not done, delta:  0.61 , i:  77
# not done, delta:  0.58 , i:  78
# not done, delta:  0.55 , i:  79
# not done, delta:  0.52 , i:  80
# not done, delta:  0.49 , i:  81
# not done, delta:  0.47 , i:  82
# not done, delta:  0.44 , i:  83
# not done, delta:  0.42 , i:  84
# not done, delta:  0.4 , i:  85
# not done, delta:  0.38 , i:  86
# not done, delta:  0.36 , i:  87
# not done, delta:  0.34 , i:  88
# not done, delta:  0.32 , i:  89
# not done, delta:  0.3 , i:  90
# not done, delta:  0.29 , i:  91
# not done, delta:  0.27 , i:  92
# not done, delta:  0.26 , i:  93
# not done, delta:  0.25 , i:  94
# not done, delta:  0.23 , i:  95
# not done, delta:  0.22 , i:  96
# not done, delta:  0.21 , i:  97
# not done, delta:  0.2 , i:  98
# not done, delta:  0.19 , i:  99
# not done, delta:  128.83 , i:  1
# not done, delta:  116.74 , i:  2
# not done, delta:  106.89 , i:  3
# not done, delta:  97.4 , i:  4
# not done, delta:  88.74 , i:  5
# not done, delta:  80.85 , i:  6
# not done, delta:  73.67 , i:  7
# not done, delta:  67.12 , i:  8
# not done, delta:  61.15 , i:  9
# not done, delta:  55.72 , i:  10
# not done, delta:  50.77 , i:  11
# not done, delta:  46.25 , i:  12
# not done, delta:  42.14 , i:  13
# not done, delta:  38.4 , i:  14
# not done, delta:  34.98 , i:  15
# not done, delta:  31.87 , i:  16
# not done, delta:  29.04 , i:  17
# not done, delta:  26.46 , i:  18
# not done, delta:  24.11 , i:  19
# not done, delta:  21.97 , i:  20
# not done, delta:  20.01 , i:  21
# not done, delta:  18.23 , i:  22
# not done, delta:  16.61 , i:  23
# not done, delta:  15.14 , i:  24
# not done, delta:  13.79 , i:  25
# not done, delta:  12.57 , i:  26
# not done, delta:  11.45 , i:  27
# not done, delta:  10.43 , i:  28
# not done, delta:  9.5 , i:  29
# not done, delta:  8.66 , i:  30
# not done, delta:  7.89 , i:  31
# not done, delta:  7.19 , i:  32
# not done, delta:  6.55 , i:  33
# not done, delta:  5.97 , i:  34
# not done, delta:  5.44 , i:  35
# not done, delta:  4.95 , i:  36
# not done, delta:  4.51 , i:  37
# not done, delta:  4.11 , i:  38
# not done, delta:  3.75 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.11 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.48 , i:  49
# not done, delta:  1.35 , i:  50
# not done, delta:  1.23 , i:  51
# not done, delta:  1.12 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.85 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.37 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.08 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.2 , i:  1
# not done, delta:  71.5 , i:  2
# not done, delta:  67.2 , i:  3
# not done, delta:  63.24 , i:  4
# not done, delta:  59.6 , i:  5
# not done, delta:  56.22 , i:  6
# not done, delta:  53.07 , i:  7
# not done, delta:  50.13 , i:  8
# not done, delta:  47.59 , i:  9
# not done, delta:  45.19 , i:  10
# not done, delta:  42.89 , i:  11
# not done, delta:  40.7 , i:  12
# not done, delta:  38.61 , i:  13
# not done, delta:  36.62 , i:  14
# not done, delta:  34.72 , i:  15
# not done, delta:  32.92 , i:  16
# not done, delta:  31.21 , i:  17
# not done, delta:  29.58 , i:  18
# not done, delta:  28.04 , i:  19
# not done, delta:  26.57 , i:  20
# not done, delta:  25.18 , i:  21
# not done, delta:  23.86 , i:  22
# not done, delta:  22.61 , i:  23
# not done, delta:  21.43 , i:  24
# not done, delta:  20.3 , i:  25
# not done, delta:  19.24 , i:  26
# not done, delta:  18.23 , i:  27
# not done, delta:  17.27 , i:  28
# not done, delta:  16.37 , i:  29
# not done, delta:  15.51 , i:  30
# not done, delta:  14.69 , i:  31
# not done, delta:  13.92 , i:  32
# not done, delta:  13.19 , i:  33
# not done, delta:  12.5 , i:  34
# not done, delta:  11.84 , i:  35
# not done, delta:  11.22 , i:  36
# not done, delta:  10.63 , i:  37
# not done, delta:  10.07 , i:  38
# not done, delta:  9.54 , i:  39
# not done, delta:  9.04 , i:  40
# not done, delta:  8.57 , i:  41
# not done, delta:  8.12 , i:  42
# not done, delta:  7.69 , i:  43
# not done, delta:  7.29 , i:  44
# not done, delta:  6.9 , i:  45
# not done, delta:  6.54 , i:  46
# not done, delta:  6.2 , i:  47
# not done, delta:  5.87 , i:  48
# not done, delta:  5.56 , i:  49
# not done, delta:  5.27 , i:  50
# not done, delta:  4.99 , i:  51
# not done, delta:  4.73 , i:  52
# not done, delta:  4.48 , i:  53
# not done, delta:  4.25 , i:  54
# not done, delta:  4.02 , i:  55
# not done, delta:  3.81 , i:  56
# not done, delta:  3.61 , i:  57
# not done, delta:  3.42 , i:  58
# not done, delta:  3.24 , i:  59
# not done, delta:  3.07 , i:  60
# not done, delta:  2.91 , i:  61
# not done, delta:  2.76 , i:  62
# not done, delta:  2.61 , i:  63
# not done, delta:  2.48 , i:  64
# not done, delta:  2.35 , i:  65
# not done, delta:  2.22 , i:  66
# not done, delta:  2.11 , i:  67
# not done, delta:  2.0 , i:  68
# not done, delta:  1.89 , i:  69
# not done, delta:  1.79 , i:  70
# not done, delta:  1.7 , i:  71
# not done, delta:  1.61 , i:  72
# not done, delta:  1.52 , i:  73
# not done, delta:  1.44 , i:  74
# not done, delta:  1.37 , i:  75
# not done, delta:  1.3 , i:  76
# not done, delta:  1.23 , i:  77
# not done, delta:  1.16 , i:  78
# not done, delta:  1.1 , i:  79
# not done, delta:  1.04 , i:  80
# not done, delta:  0.99 , i:  81
# not done, delta:  0.94 , i:  82
# not done, delta:  0.89 , i:  83
# not done, delta:  0.84 , i:  84
# not done, delta:  0.8 , i:  85
# not done, delta:  0.76 , i:  86
# not done, delta:  0.72 , i:  87
# not done, delta:  0.68 , i:  88
# not done, delta:  0.64 , i:  89
# not done, delta:  0.61 , i:  90
# not done, delta:  0.58 , i:  91
# not done, delta:  0.55 , i:  92
# not done, delta:  0.52 , i:  93
# not done, delta:  0.49 , i:  94
# not done, delta:  0.46 , i:  95
# not done, delta:  0.44 , i:  96
# not done, delta:  0.42 , i:  97
# not done, delta:  0.4 , i:  98
# not done, delta:  0.37 , i:  99
# not done, delta:  128.54 , i:  1
# not done, delta:  116.47 , i:  2
# not done, delta:  106.65 , i:  3
# not done, delta:  97.18 , i:  4
# not done, delta:  88.54 , i:  5
# not done, delta:  80.67 , i:  6
# not done, delta:  73.5 , i:  7
# not done, delta:  66.97 , i:  8
# not done, delta:  61.02 , i:  9
# not done, delta:  55.59 , i:  10
# not done, delta:  50.65 , i:  11
# not done, delta:  46.15 , i:  12
# not done, delta:  42.05 , i:  13
# not done, delta:  38.31 , i:  14
# not done, delta:  34.91 , i:  15
# not done, delta:  31.8 , i:  16
# not done, delta:  28.98 , i:  17
# not done, delta:  26.4 , i:  18
# not done, delta:  24.05 , i:  19
# not done, delta:  21.92 , i:  20
# not done, delta:  19.97 , i:  21
# not done, delta:  18.19 , i:  22
# not done, delta:  16.58 , i:  23
# not done, delta:  15.1 , i:  24
# not done, delta:  13.76 , i:  25
# not done, delta:  12.54 , i:  26
# not done, delta:  11.42 , i:  27
# not done, delta:  10.41 , i:  28
# not done, delta:  9.48 , i:  29
# not done, delta:  8.64 , i:  30
# not done, delta:  7.87 , i:  31
# not done, delta:  7.17 , i:  32
# not done, delta:  6.54 , i:  33
# not done, delta:  5.95 , i:  34
# not done, delta:  5.42 , i:  35
# not done, delta:  4.94 , i:  36
# not done, delta:  4.5 , i:  37
# not done, delta:  4.1 , i:  38
# not done, delta:  3.74 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.1 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.47 , i:  49
# not done, delta:  1.34 , i:  50
# not done, delta:  1.22 , i:  51
# not done, delta:  1.11 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.84 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.36 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.07 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.21 , i:  1
# not done, delta:  71.5 , i:  2
# not done, delta:  67.2 , i:  3
# not done, delta:  63.24 , i:  4
# not done, delta:  59.6 , i:  5
# not done, delta:  56.22 , i:  6
# not done, delta:  53.07 , i:  7
# not done, delta:  50.13 , i:  8
# not done, delta:  47.59 , i:  9
# not done, delta:  45.19 , i:  10
# not done, delta:  42.89 , i:  11
# not done, delta:  40.7 , i:  12
# not done, delta:  38.61 , i:  13
# not done, delta:  36.62 , i:  14
# not done, delta:  34.72 , i:  15
# not done, delta:  32.92 , i:  16
# not done, delta:  31.21 , i:  17
# not done, delta:  29.58 , i:  18
# not done, delta:  28.04 , i:  19
# not done, delta:  26.57 , i:  20
# not done, delta:  25.18 , i:  21
# not done, delta:  23.86 , i:  22
# not done, delta:  22.61 , i:  23
# not done, delta:  21.43 , i:  24
# not done, delta:  20.3 , i:  25
# not done, delta:  19.24 , i:  26
# not done, delta:  18.23 , i:  27
# not done, delta:  17.27 , i:  28
# not done, delta:  16.37 , i:  29
# not done, delta:  15.51 , i:  30
# not done, delta:  14.69 , i:  31
# not done, delta:  13.92 , i:  32
# not done, delta:  13.19 , i:  33
# not done, delta:  12.5 , i:  34
# not done, delta:  11.84 , i:  35
# not done, delta:  11.22 , i:  36
# not done, delta:  10.63 , i:  37
# not done, delta:  10.07 , i:  38
# not done, delta:  9.54 , i:  39
# not done, delta:  9.04 , i:  40
# not done, delta:  8.57 , i:  41
# not done, delta:  8.12 , i:  42
# not done, delta:  7.69 , i:  43
# not done, delta:  7.29 , i:  44
# not done, delta:  6.9 , i:  45
# not done, delta:  6.54 , i:  46
# not done, delta:  6.2 , i:  47
# not done, delta:  5.87 , i:  48
# not done, delta:  5.56 , i:  49
# not done, delta:  5.27 , i:  50
# not done, delta:  4.99 , i:  51
# not done, delta:  4.73 , i:  52
# not done, delta:  4.48 , i:  53
# not done, delta:  4.25 , i:  54
# not done, delta:  4.02 , i:  55
# not done, delta:  3.81 , i:  56
# not done, delta:  3.61 , i:  57
# not done, delta:  3.42 , i:  58
# not done, delta:  3.24 , i:  59
# not done, delta:  3.07 , i:  60
# not done, delta:  2.91 , i:  61
# not done, delta:  2.76 , i:  62
# not done, delta:  2.61 , i:  63
# not done, delta:  2.48 , i:  64
# not done, delta:  2.35 , i:  65
# not done, delta:  2.22 , i:  66
# not done, delta:  2.11 , i:  67
# not done, delta:  2.0 , i:  68
# not done, delta:  1.89 , i:  69
# not done, delta:  1.79 , i:  70
# not done, delta:  1.7 , i:  71
# not done, delta:  1.61 , i:  72
# not done, delta:  1.52 , i:  73
# not done, delta:  1.44 , i:  74
# not done, delta:  1.37 , i:  75
# not done, delta:  1.3 , i:  76
# not done, delta:  1.23 , i:  77
# not done, delta:  1.16 , i:  78
# not done, delta:  1.1 , i:  79
# not done, delta:  1.04 , i:  80
# not done, delta:  0.99 , i:  81
# not done, delta:  0.94 , i:  82
# not done, delta:  0.89 , i:  83
# not done, delta:  0.84 , i:  84
# not done, delta:  0.8 , i:  85
# not done, delta:  0.76 , i:  86
# not done, delta:  0.72 , i:  87
# not done, delta:  0.68 , i:  88
# not done, delta:  0.64 , i:  89
# not done, delta:  0.61 , i:  90
# not done, delta:  0.58 , i:  91
# not done, delta:  0.55 , i:  92
# not done, delta:  0.52 , i:  93
# not done, delta:  0.49 , i:  94
# not done, delta:  0.46 , i:  95
# not done, delta:  0.44 , i:  96
# not done, delta:  0.42 , i:  97
# not done, delta:  0.4 , i:  98
# not done, delta:  0.37 , i:  99
# not done, delta:  128.54 , i:  1
# not done, delta:  116.47 , i:  2
# not done, delta:  106.65 , i:  3
# not done, delta:  97.18 , i:  4
# not done, delta:  88.54 , i:  5
# not done, delta:  80.67 , i:  6
# not done, delta:  73.5 , i:  7
# not done, delta:  66.97 , i:  8
# not done, delta:  61.02 , i:  9
# not done, delta:  55.59 , i:  10
# not done, delta:  50.65 , i:  11
# not done, delta:  46.15 , i:  12
# not done, delta:  42.05 , i:  13
# not done, delta:  38.31 , i:  14
# not done, delta:  34.91 , i:  15
# not done, delta:  31.8 , i:  16
# not done, delta:  28.98 , i:  17
# not done, delta:  26.4 , i:  18
# not done, delta:  24.05 , i:  19
# not done, delta:  21.92 , i:  20
# not done, delta:  19.97 , i:  21
# not done, delta:  18.19 , i:  22
# not done, delta:  16.58 , i:  23
# not done, delta:  15.1 , i:  24
# not done, delta:  13.76 , i:  25
# not done, delta:  12.54 , i:  26
# not done, delta:  11.42 , i:  27
# not done, delta:  10.41 , i:  28
# not done, delta:  9.48 , i:  29
# not done, delta:  8.64 , i:  30
# not done, delta:  7.87 , i:  31
# not done, delta:  7.17 , i:  32
# not done, delta:  6.54 , i:  33
# not done, delta:  5.95 , i:  34
# not done, delta:  5.42 , i:  35
# not done, delta:  4.94 , i:  36
# not done, delta:  4.5 , i:  37
# not done, delta:  4.1 , i:  38
# not done, delta:  3.74 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.1 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.47 , i:  49
# not done, delta:  1.34 , i:  50
# not done, delta:  1.22 , i:  51
# not done, delta:  1.11 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.84 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.36 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.07 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.21 , i:  1
# not done, delta:  71.5 , i:  2
# not done, delta:  67.2 , i:  3
# not done, delta:  63.24 , i:  4
# not done, delta:  59.6 , i:  5
# not done, delta:  56.22 , i:  6
# not done, delta:  53.07 , i:  7
# not done, delta:  50.13 , i:  8
# not done, delta:  47.59 , i:  9
# not done, delta:  45.19 , i:  10
# not done, delta:  42.89 , i:  11
# not done, delta:  40.7 , i:  12
# not done, delta:  38.61 , i:  13
# not done, delta:  36.62 , i:  14
# not done, delta:  34.72 , i:  15
# not done, delta:  32.92 , i:  16
# not done, delta:  31.21 , i:  17
# not done, delta:  29.58 , i:  18
# not done, delta:  28.04 , i:  19
# not done, delta:  26.57 , i:  20
# not done, delta:  25.18 , i:  21
# not done, delta:  23.86 , i:  22
# not done, delta:  22.61 , i:  23
# not done, delta:  21.43 , i:  24
# not done, delta:  20.3 , i:  25
# not done, delta:  19.24 , i:  26
# not done, delta:  18.23 , i:  27
# not done, delta:  17.27 , i:  28
# not done, delta:  16.37 , i:  29
# not done, delta:  15.51 , i:  30
# not done, delta:  14.69 , i:  31
# not done, delta:  13.92 , i:  32
# not done, delta:  13.19 , i:  33
# not done, delta:  12.5 , i:  34
# not done, delta:  11.84 , i:  35
# not done, delta:  11.22 , i:  36
# not done, delta:  10.63 , i:  37
# not done, delta:  10.07 , i:  38
# not done, delta:  9.54 , i:  39
# not done, delta:  9.04 , i:  40
# not done, delta:  8.57 , i:  41
# not done, delta:  8.12 , i:  42
# not done, delta:  7.69 , i:  43
# not done, delta:  7.29 , i:  44
# not done, delta:  6.9 , i:  45
# not done, delta:  6.54 , i:  46
# not done, delta:  6.2 , i:  47
# not done, delta:  5.87 , i:  48
# not done, delta:  5.56 , i:  49
# not done, delta:  5.27 , i:  50
# not done, delta:  4.99 , i:  51
# not done, delta:  4.73 , i:  52
# not done, delta:  4.48 , i:  53
# not done, delta:  4.25 , i:  54
# not done, delta:  4.02 , i:  55
# not done, delta:  3.81 , i:  56
# not done, delta:  3.61 , i:  57
# not done, delta:  3.42 , i:  58
# not done, delta:  3.24 , i:  59
# not done, delta:  3.07 , i:  60
# not done, delta:  2.91 , i:  61
# not done, delta:  2.76 , i:  62
# not done, delta:  2.61 , i:  63
# not done, delta:  2.48 , i:  64
# not done, delta:  2.35 , i:  65
# not done, delta:  2.22 , i:  66
# not done, delta:  2.11 , i:  67
# not done, delta:  2.0 , i:  68
# not done, delta:  1.89 , i:  69
# not done, delta:  1.79 , i:  70
# not done, delta:  1.7 , i:  71
# not done, delta:  1.61 , i:  72
# not done, delta:  1.52 , i:  73
# not done, delta:  1.44 , i:  74
# not done, delta:  1.37 , i:  75
# not done, delta:  1.3 , i:  76
# not done, delta:  1.23 , i:  77
# not done, delta:  1.16 , i:  78
# not done, delta:  1.1 , i:  79
# not done, delta:  1.04 , i:  80
# not done, delta:  0.99 , i:  81
# not done, delta:  0.94 , i:  82
# not done, delta:  0.89 , i:  83
# not done, delta:  0.84 , i:  84
# not done, delta:  0.8 , i:  85
# not done, delta:  0.76 , i:  86
# not done, delta:  0.72 , i:  87
# not done, delta:  0.68 , i:  88
# not done, delta:  0.64 , i:  89
# not done, delta:  0.61 , i:  90
# not done, delta:  0.58 , i:  91
# not done, delta:  0.55 , i:  92
# not done, delta:  0.52 , i:  93
# not done, delta:  0.49 , i:  94
# not done, delta:  0.46 , i:  95
# not done, delta:  0.44 , i:  96
# not done, delta:  0.42 , i:  97
# not done, delta:  0.4 , i:  98
# not done, delta:  0.37 , i:  99
# not done, delta:  128.54 , i:  1
# not done, delta:  116.47 , i:  2
# not done, delta:  106.65 , i:  3
# not done, delta:  97.18 , i:  4
# not done, delta:  88.54 , i:  5
# not done, delta:  80.67 , i:  6
# not done, delta:  73.5 , i:  7
# not done, delta:  66.97 , i:  8
# not done, delta:  61.02 , i:  9
# not done, delta:  55.59 , i:  10
# not done, delta:  50.65 , i:  11
# not done, delta:  46.15 , i:  12
# not done, delta:  42.05 , i:  13
# not done, delta:  38.31 , i:  14
# not done, delta:  34.91 , i:  15
# not done, delta:  31.8 , i:  16
# not done, delta:  28.98 , i:  17
# not done, delta:  26.4 , i:  18
# not done, delta:  24.05 , i:  19
# not done, delta:  21.92 , i:  20
# not done, delta:  19.97 , i:  21
# not done, delta:  18.19 , i:  22
# not done, delta:  16.58 , i:  23
# not done, delta:  15.1 , i:  24
# not done, delta:  13.76 , i:  25
# not done, delta:  12.54 , i:  26
# not done, delta:  11.42 , i:  27
# not done, delta:  10.41 , i:  28
# not done, delta:  9.48 , i:  29
# not done, delta:  8.64 , i:  30
# not done, delta:  7.87 , i:  31
# not done, delta:  7.17 , i:  32
# not done, delta:  6.54 , i:  33
# not done, delta:  5.95 , i:  34
# not done, delta:  5.42 , i:  35
# not done, delta:  4.94 , i:  36
# not done, delta:  4.5 , i:  37
# not done, delta:  4.1 , i:  38
# not done, delta:  3.74 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.1 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.47 , i:  49
# not done, delta:  1.34 , i:  50
# not done, delta:  1.22 , i:  51
# not done, delta:  1.11 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.84 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.36 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.07 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.21 , i:  1
# not done, delta:  71.5 , i:  2
# not done, delta:  67.2 , i:  3
# not done, delta:  63.24 , i:  4
# not done, delta:  59.6 , i:  5
# not done, delta:  56.22 , i:  6
# not done, delta:  53.07 , i:  7
# not done, delta:  50.13 , i:  8
# not done, delta:  47.59 , i:  9
# not done, delta:  45.19 , i:  10
# not done, delta:  42.89 , i:  11
# not done, delta:  40.7 , i:  12
# not done, delta:  38.61 , i:  13
# not done, delta:  36.62 , i:  14
# not done, delta:  34.72 , i:  15
# not done, delta:  32.92 , i:  16
# not done, delta:  31.21 , i:  17
# not done, delta:  29.58 , i:  18
# not done, delta:  28.04 , i:  19
# not done, delta:  26.57 , i:  20
# not done, delta:  25.18 , i:  21
# not done, delta:  23.86 , i:  22
# not done, delta:  22.61 , i:  23
# not done, delta:  21.43 , i:  24
# not done, delta:  20.3 , i:  25
# not done, delta:  19.24 , i:  26
# not done, delta:  18.23 , i:  27
# not done, delta:  17.27 , i:  28
# not done, delta:  16.37 , i:  29
# not done, delta:  15.51 , i:  30
# not done, delta:  14.69 , i:  31
# not done, delta:  13.92 , i:  32
# not done, delta:  13.19 , i:  33
# not done, delta:  12.5 , i:  34
# not done, delta:  11.84 , i:  35
# not done, delta:  11.22 , i:  36
# not done, delta:  10.63 , i:  37
# not done, delta:  10.07 , i:  38
# not done, delta:  9.54 , i:  39
# not done, delta:  9.04 , i:  40
# not done, delta:  8.57 , i:  41
# not done, delta:  8.12 , i:  42
# not done, delta:  7.69 , i:  43
# not done, delta:  7.29 , i:  44
# not done, delta:  6.9 , i:  45
# not done, delta:  6.54 , i:  46
# not done, delta:  6.2 , i:  47
# not done, delta:  5.87 , i:  48
# not done, delta:  5.56 , i:  49
# not done, delta:  5.27 , i:  50
# not done, delta:  4.99 , i:  51
# not done, delta:  4.73 , i:  52
# not done, delta:  4.48 , i:  53
# not done, delta:  4.25 , i:  54
# not done, delta:  4.02 , i:  55
# not done, delta:  3.81 , i:  56
# not done, delta:  3.61 , i:  57
# not done, delta:  3.42 , i:  58
# not done, delta:  3.24 , i:  59
# not done, delta:  3.07 , i:  60
# not done, delta:  2.91 , i:  61
# not done, delta:  2.76 , i:  62
# not done, delta:  2.61 , i:  63
# not done, delta:  2.48 , i:  64
# not done, delta:  2.35 , i:  65
# not done, delta:  2.22 , i:  66
# not done, delta:  2.11 , i:  67
# not done, delta:  2.0 , i:  68
# not done, delta:  1.89 , i:  69
# not done, delta:  1.79 , i:  70
# not done, delta:  1.7 , i:  71
# not done, delta:  1.61 , i:  72
# not done, delta:  1.52 , i:  73
# not done, delta:  1.44 , i:  74
# not done, delta:  1.37 , i:  75
# not done, delta:  1.3 , i:  76
# not done, delta:  1.23 , i:  77
# not done, delta:  1.16 , i:  78
# not done, delta:  1.1 , i:  79
# not done, delta:  1.04 , i:  80
# not done, delta:  0.99 , i:  81
# not done, delta:  0.94 , i:  82
# not done, delta:  0.89 , i:  83
# not done, delta:  0.84 , i:  84
# not done, delta:  0.8 , i:  85
# not done, delta:  0.76 , i:  86
# not done, delta:  0.72 , i:  87
# not done, delta:  0.68 , i:  88
# not done, delta:  0.64 , i:  89
# not done, delta:  0.61 , i:  90
# not done, delta:  0.58 , i:  91
# not done, delta:  0.55 , i:  92
# not done, delta:  0.52 , i:  93
# not done, delta:  0.49 , i:  94
# not done, delta:  0.46 , i:  95
# not done, delta:  0.44 , i:  96
# not done, delta:  0.42 , i:  97
# not done, delta:  0.4 , i:  98
# not done, delta:  0.37 , i:  99
# not done, delta:  128.54 , i:  1
# not done, delta:  116.47 , i:  2
# not done, delta:  106.65 , i:  3
# not done, delta:  97.18 , i:  4
# not done, delta:  88.54 , i:  5
# not done, delta:  80.67 , i:  6
# not done, delta:  73.5 , i:  7
# not done, delta:  66.97 , i:  8
# not done, delta:  61.02 , i:  9
# not done, delta:  55.59 , i:  10
# not done, delta:  50.65 , i:  11
# not done, delta:  46.15 , i:  12
# not done, delta:  42.05 , i:  13
# not done, delta:  38.31 , i:  14
# not done, delta:  34.91 , i:  15
# not done, delta:  31.8 , i:  16
# not done, delta:  28.98 , i:  17
# not done, delta:  26.4 , i:  18
# not done, delta:  24.05 , i:  19
# not done, delta:  21.92 , i:  20
# not done, delta:  19.97 , i:  21
# not done, delta:  18.19 , i:  22
# not done, delta:  16.58 , i:  23
# not done, delta:  15.1 , i:  24
# not done, delta:  13.76 , i:  25
# not done, delta:  12.54 , i:  26
# not done, delta:  11.42 , i:  27
# not done, delta:  10.41 , i:  28
# not done, delta:  9.48 , i:  29
# not done, delta:  8.64 , i:  30
# not done, delta:  7.87 , i:  31
# not done, delta:  7.17 , i:  32
# not done, delta:  6.54 , i:  33
# not done, delta:  5.95 , i:  34
# not done, delta:  5.42 , i:  35
# not done, delta:  4.94 , i:  36
# not done, delta:  4.5 , i:  37
# not done, delta:  4.1 , i:  38
# not done, delta:  3.74 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.1 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.47 , i:  49
# not done, delta:  1.34 , i:  50
# not done, delta:  1.22 , i:  51
# not done, delta:  1.11 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.84 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.36 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.07 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.21 , i:  1
# not done, delta:  71.5 , i:  2
# not done, delta:  67.2 , i:  3
# not done, delta:  63.24 , i:  4
# not done, delta:  59.6 , i:  5
# not done, delta:  56.22 , i:  6
# not done, delta:  53.07 , i:  7
# not done, delta:  50.13 , i:  8
# not done, delta:  47.59 , i:  9
# not done, delta:  45.19 , i:  10
# not done, delta:  42.89 , i:  11
# not done, delta:  40.7 , i:  12
# not done, delta:  38.61 , i:  13
# not done, delta:  36.62 , i:  14
# not done, delta:  34.72 , i:  15
# not done, delta:  32.92 , i:  16
# not done, delta:  31.21 , i:  17
# not done, delta:  29.58 , i:  18
# not done, delta:  28.04 , i:  19
# not done, delta:  26.57 , i:  20
# not done, delta:  25.18 , i:  21
# not done, delta:  23.86 , i:  22
# not done, delta:  22.61 , i:  23
# not done, delta:  21.43 , i:  24
# not done, delta:  20.3 , i:  25
# not done, delta:  19.24 , i:  26
# not done, delta:  18.23 , i:  27
# not done, delta:  17.27 , i:  28
# not done, delta:  16.37 , i:  29
# not done, delta:  15.51 , i:  30
# not done, delta:  14.69 , i:  31
# not done, delta:  13.92 , i:  32
# not done, delta:  13.19 , i:  33
# not done, delta:  12.5 , i:  34
# not done, delta:  11.84 , i:  35
# not done, delta:  11.22 , i:  36
# not done, delta:  10.63 , i:  37
# not done, delta:  10.07 , i:  38
# not done, delta:  9.54 , i:  39
# not done, delta:  9.04 , i:  40
# not done, delta:  8.57 , i:  41
# not done, delta:  8.12 , i:  42
# not done, delta:  7.69 , i:  43
# not done, delta:  7.29 , i:  44
# not done, delta:  6.9 , i:  45
# not done, delta:  6.54 , i:  46
# not done, delta:  6.2 , i:  47
# not done, delta:  5.87 , i:  48
# not done, delta:  5.56 , i:  49
# not done, delta:  5.27 , i:  50
# not done, delta:  4.99 , i:  51
# not done, delta:  4.73 , i:  52
# not done, delta:  4.48 , i:  53
# not done, delta:  4.25 , i:  54
# not done, delta:  4.02 , i:  55
# not done, delta:  3.81 , i:  56
# not done, delta:  3.61 , i:  57
# not done, delta:  3.42 , i:  58
# not done, delta:  3.24 , i:  59
# not done, delta:  3.07 , i:  60
# not done, delta:  2.91 , i:  61
# not done, delta:  2.76 , i:  62
# not done, delta:  2.61 , i:  63
# not done, delta:  2.48 , i:  64
# not done, delta:  2.35 , i:  65
# not done, delta:  2.22 , i:  66
# not done, delta:  2.11 , i:  67
# not done, delta:  2.0 , i:  68
# not done, delta:  1.89 , i:  69
# not done, delta:  1.79 , i:  70
# not done, delta:  1.7 , i:  71
# not done, delta:  1.61 , i:  72
# not done, delta:  1.52 , i:  73
# not done, delta:  1.44 , i:  74
# not done, delta:  1.37 , i:  75
# not done, delta:  1.3 , i:  76
# not done, delta:  1.23 , i:  77
# not done, delta:  1.16 , i:  78
# not done, delta:  1.1 , i:  79
# not done, delta:  1.04 , i:  80
# not done, delta:  0.99 , i:  81
# not done, delta:  0.94 , i:  82
# not done, delta:  0.89 , i:  83
# not done, delta:  0.84 , i:  84
# not done, delta:  0.8 , i:  85
# not done, delta:  0.76 , i:  86
# not done, delta:  0.72 , i:  87
# not done, delta:  0.68 , i:  88
# not done, delta:  0.64 , i:  89
# not done, delta:  0.61 , i:  90
# not done, delta:  0.58 , i:  91
# not done, delta:  0.55 , i:  92
# not done, delta:  0.52 , i:  93
# not done, delta:  0.49 , i:  94
# not done, delta:  0.46 , i:  95
# not done, delta:  0.44 , i:  96
# not done, delta:  0.42 , i:  97
# not done, delta:  0.4 , i:  98
# not done, delta:  0.37 , i:  99
# not done, delta:  128.54 , i:  1
# not done, delta:  116.47 , i:  2
# not done, delta:  106.65 , i:  3
# not done, delta:  97.18 , i:  4
# not done, delta:  88.54 , i:  5
# not done, delta:  80.67 , i:  6
# not done, delta:  73.5 , i:  7
# not done, delta:  66.97 , i:  8
# not done, delta:  61.02 , i:  9
# not done, delta:  55.59 , i:  10
# not done, delta:  50.65 , i:  11
# not done, delta:  46.15 , i:  12
# not done, delta:  42.05 , i:  13
# not done, delta:  38.31 , i:  14
# not done, delta:  34.91 , i:  15
# not done, delta:  31.8 , i:  16
# not done, delta:  28.98 , i:  17
# not done, delta:  26.4 , i:  18
# not done, delta:  24.05 , i:  19
# not done, delta:  21.92 , i:  20
# not done, delta:  19.97 , i:  21
# not done, delta:  18.19 , i:  22
# not done, delta:  16.58 , i:  23
# not done, delta:  15.1 , i:  24
# not done, delta:  13.76 , i:  25
# not done, delta:  12.54 , i:  26
# not done, delta:  11.42 , i:  27
# not done, delta:  10.41 , i:  28
# not done, delta:  9.48 , i:  29
# not done, delta:  8.64 , i:  30
# not done, delta:  7.87 , i:  31
# not done, delta:  7.17 , i:  32
# not done, delta:  6.54 , i:  33
# not done, delta:  5.95 , i:  34
# not done, delta:  5.42 , i:  35
# not done, delta:  4.94 , i:  36
# not done, delta:  4.5 , i:  37
# not done, delta:  4.1 , i:  38
# not done, delta:  3.74 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.1 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.47 , i:  49
# not done, delta:  1.34 , i:  50
# not done, delta:  1.22 , i:  51
# not done, delta:  1.11 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.84 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.36 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.07 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.21 , i:  1
# not done, delta:  71.5 , i:  2
# not done, delta:  67.2 , i:  3
# not done, delta:  63.24 , i:  4
# not done, delta:  59.6 , i:  5
# not done, delta:  56.22 , i:  6
# not done, delta:  53.07 , i:  7
# not done, delta:  50.13 , i:  8
# not done, delta:  47.59 , i:  9
# not done, delta:  45.19 , i:  10
# not done, delta:  42.89 , i:  11
# not done, delta:  40.7 , i:  12
# not done, delta:  38.61 , i:  13
# not done, delta:  36.62 , i:  14
# not done, delta:  34.72 , i:  15
# not done, delta:  32.92 , i:  16
# not done, delta:  31.21 , i:  17
# not done, delta:  29.58 , i:  18
# not done, delta:  28.04 , i:  19
# not done, delta:  26.57 , i:  20
# not done, delta:  25.18 , i:  21
# not done, delta:  23.86 , i:  22
# not done, delta:  22.61 , i:  23
# not done, delta:  21.43 , i:  24
# not done, delta:  20.3 , i:  25
# not done, delta:  19.24 , i:  26
# not done, delta:  18.23 , i:  27
# not done, delta:  17.27 , i:  28
# not done, delta:  16.37 , i:  29
# not done, delta:  15.51 , i:  30
# not done, delta:  14.69 , i:  31
# not done, delta:  13.92 , i:  32
# not done, delta:  13.19 , i:  33
# not done, delta:  12.5 , i:  34
# not done, delta:  11.84 , i:  35
# not done, delta:  11.22 , i:  36
# not done, delta:  10.63 , i:  37
# not done, delta:  10.07 , i:  38
# not done, delta:  9.54 , i:  39
# not done, delta:  9.04 , i:  40
# not done, delta:  8.57 , i:  41
# not done, delta:  8.12 , i:  42
# not done, delta:  7.69 , i:  43
# not done, delta:  7.29 , i:  44
# not done, delta:  6.9 , i:  45
# not done, delta:  6.54 , i:  46
# not done, delta:  6.2 , i:  47
# not done, delta:  5.87 , i:  48
# not done, delta:  5.56 , i:  49
# not done, delta:  5.27 , i:  50
# not done, delta:  4.99 , i:  51
# not done, delta:  4.73 , i:  52
# not done, delta:  4.48 , i:  53
# not done, delta:  4.25 , i:  54
# not done, delta:  4.02 , i:  55
# not done, delta:  3.81 , i:  56
# not done, delta:  3.61 , i:  57
# not done, delta:  3.42 , i:  58
# not done, delta:  3.24 , i:  59
# not done, delta:  3.07 , i:  60
# not done, delta:  2.91 , i:  61
# not done, delta:  2.76 , i:  62
# not done, delta:  2.61 , i:  63
# not done, delta:  2.48 , i:  64
# not done, delta:  2.35 , i:  65
# not done, delta:  2.22 , i:  66
# not done, delta:  2.11 , i:  67
# not done, delta:  2.0 , i:  68
# not done, delta:  1.89 , i:  69
# not done, delta:  1.79 , i:  70
# not done, delta:  1.7 , i:  71
# not done, delta:  1.61 , i:  72
# not done, delta:  1.52 , i:  73
# not done, delta:  1.44 , i:  74
# not done, delta:  1.37 , i:  75
# not done, delta:  1.3 , i:  76
# not done, delta:  1.23 , i:  77
# not done, delta:  1.16 , i:  78
# not done, delta:  1.1 , i:  79
# not done, delta:  1.04 , i:  80
# not done, delta:  0.99 , i:  81
# not done, delta:  0.94 , i:  82
# not done, delta:  0.89 , i:  83
# not done, delta:  0.84 , i:  84
# not done, delta:  0.8 , i:  85
# not done, delta:  0.76 , i:  86
# not done, delta:  0.72 , i:  87
# not done, delta:  0.68 , i:  88
# not done, delta:  0.64 , i:  89
# not done, delta:  0.61 , i:  90
# not done, delta:  0.58 , i:  91
# not done, delta:  0.55 , i:  92
# not done, delta:  0.52 , i:  93
# not done, delta:  0.49 , i:  94
# not done, delta:  0.46 , i:  95
# not done, delta:  0.44 , i:  96
# not done, delta:  0.42 , i:  97
# not done, delta:  0.4 , i:  98
# not done, delta:  0.37 , i:  99
# not done, delta:  128.54 , i:  1
# not done, delta:  116.47 , i:  2
# not done, delta:  106.65 , i:  3
# not done, delta:  97.18 , i:  4
# not done, delta:  88.54 , i:  5
# not done, delta:  80.67 , i:  6
# not done, delta:  73.5 , i:  7
# not done, delta:  66.97 , i:  8
# not done, delta:  61.02 , i:  9
# not done, delta:  55.59 , i:  10
# not done, delta:  50.65 , i:  11
# not done, delta:  46.15 , i:  12
# not done, delta:  42.05 , i:  13
# not done, delta:  38.31 , i:  14
# not done, delta:  34.91 , i:  15
# not done, delta:  31.8 , i:  16
# not done, delta:  28.98 , i:  17
# not done, delta:  26.4 , i:  18
# not done, delta:  24.05 , i:  19
# not done, delta:  21.92 , i:  20
# not done, delta:  19.97 , i:  21
# not done, delta:  18.19 , i:  22
# not done, delta:  16.58 , i:  23
# not done, delta:  15.1 , i:  24
# not done, delta:  13.76 , i:  25
# not done, delta:  12.54 , i:  26
# not done, delta:  11.42 , i:  27
# not done, delta:  10.41 , i:  28
# not done, delta:  9.48 , i:  29
# not done, delta:  8.64 , i:  30
# not done, delta:  7.87 , i:  31
# not done, delta:  7.17 , i:  32
# not done, delta:  6.54 , i:  33
# not done, delta:  5.95 , i:  34
# not done, delta:  5.42 , i:  35
# not done, delta:  4.94 , i:  36
# not done, delta:  4.5 , i:  37
# not done, delta:  4.1 , i:  38
# not done, delta:  3.74 , i:  39
# not done, delta:  3.41 , i:  40
# not done, delta:  3.1 , i:  41
# not done, delta:  2.83 , i:  42
# not done, delta:  2.58 , i:  43
# not done, delta:  2.35 , i:  44
# not done, delta:  2.14 , i:  45
# not done, delta:  1.95 , i:  46
# not done, delta:  1.78 , i:  47
# not done, delta:  1.62 , i:  48
# not done, delta:  1.47 , i:  49
# not done, delta:  1.34 , i:  50
# not done, delta:  1.22 , i:  51
# not done, delta:  1.11 , i:  52
# not done, delta:  1.02 , i:  53
# not done, delta:  0.93 , i:  54
# not done, delta:  0.84 , i:  55
# not done, delta:  0.77 , i:  56
# not done, delta:  0.7 , i:  57
# not done, delta:  0.64 , i:  58
# not done, delta:  0.58 , i:  59
# not done, delta:  0.53 , i:  60
# not done, delta:  0.48 , i:  61
# not done, delta:  0.44 , i:  62
# not done, delta:  0.4 , i:  63
# not done, delta:  0.36 , i:  64
# not done, delta:  0.33 , i:  65
# not done, delta:  0.3 , i:  66
# not done, delta:  0.28 , i:  67
# not done, delta:  0.25 , i:  68
# not done, delta:  0.23 , i:  69
# not done, delta:  0.21 , i:  70
# not done, delta:  0.19 , i:  71
# not done, delta:  0.17 , i:  72
# not done, delta:  0.16 , i:  73
# not done, delta:  0.14 , i:  74
# not done, delta:  0.13 , i:  75
# not done, delta:  0.12 , i:  76
# not done, delta:  0.11 , i:  77
# not done, delta:  0.1 , i:  78
# not done, delta:  0.09 , i:  79
# not done, delta:  0.08 , i:  80
# not done, delta:  0.07 , i:  81
# not done, delta:  0.07 , i:  82
# not done, delta:  0.06 , i:  83
# not done, delta:  0.06 , i:  84
# not done, delta:  0.05 , i:  85
# not done, delta:  0.05 , i:  86
# not done, delta:  0.04 , i:  87
# not done, delta:  0.04 , i:  88
# not done, delta:  0.04 , i:  89
# not done, delta:  0.03 , i:  90
# not done, delta:  0.03 , i:  91
# not done, delta:  0.03 , i:  92
# not done, delta:  0.02 , i:  93
# not done, delta:  0.02 , i:  94
# not done, delta:  0.02 , i:  95
# not done, delta:  0.02 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  76.21 , i:  1
# not done, delta:  71.5 , i:  2
# ...
# not done, delta:  1.42 , i:  81
# not done, delta:  1.35 , i:  82
# not done, delta:  1.28 , i:  83
# not done, delta:  1.21 , i:  84
# not done, delta:  1.15 , i:  85
# not done, delta:  1.09 , i:  86
# not done, delta:  1.03 , i:  87
# not done, delta:  0.98 , i:  88
# not done, delta:  0.93 , i:  89
# not done, delta:  0.88 , i:  90
# not done, delta:  0.83 , i:  91
# not done, delta:  0.79 , i:  92
# not done, delta:  0.75 , i:  93
# not done, delta:  0.71 , i:  94
# not done, delta:  0.67 , i:  95
# not done, delta:  0.63 , i:  96
# not done, delta:  0.6 , i:  97
# not done, delta:  0.57 , i:  98
# not done, delta:  0.54 , i:  99
# not done, delta:  185.06 , i:  1
# not done, delta:  167.68 , i:  2
# not done, delta:  153.54 , i:  3
# not done, delta:  139.9 , i:  4
# not done, delta:  127.47 , i:  5
# not done, delta:  116.14 , i:  6
# not done, delta:  105.81 , i:  7
# not done, delta:  96.41 , i:  8
# not done, delta:  87.84 , i:  9
# not done, delta:  80.03 , i:  10
# not done, delta:  72.92 , i:  11
# not done, delta:  66.44 , i:  12
# not done, delta:  60.53 , i:  13
# not done, delta:  55.15 , i:  14
# not done, delta:  50.25 , i:  15
# not done, delta:  45.79 , i:  16
# not done, delta:  41.72 , i:  17
# not done, delta:  38.01 , i:  18
# not done, delta:  34.63 , i:  19
# not done, delta:  31.55 , i:  20
# not done, delta:  28.75 , i:  21
# not done, delta:  26.19 , i:  22
# not done, delta:  23.86 , i:  23
# not done, delta:  21.74 , i:  24
# not done, delta:  19.81 , i:  25
# not done, delta:  18.05 , i:  26
# not done, delta:  16.45 , i:  27
# not done, delta:  14.98 , i:  28
# not done, delta:  13.65 , i:  29
# not done, delta:  12.44 , i:  30
# not done, delta:  11.33 , i:  31
# not done, delta:  10.33 , i:  32
# not done, delta:  9.41 , i:  33
# not done, delta:  8.57 , i:  34
# not done, delta:  7.81 , i:  35
# not done, delta:  7.12 , i:  36
# not done, delta:  6.48 , i:  37
# not done, delta:  5.91 , i:  38
# not done, delta:  5.38 , i:  39
# not done, delta:  4.9 , i:  40
# not done, delta:  4.47 , i:  41
# not done, delta:  4.07 , i:  42
# not done, delta:  3.71 , i:  43
# not done, delta:  3.38 , i:  44
# not done, delta:  3.08 , i:  45
# not done, delta:  2.81 , i:  46
# not done, delta:  2.56 , i:  47
# not done, delta:  2.33 , i:  48
# not done, delta:  2.12 , i:  49
# not done, delta:  1.93 , i:  50
# not done, delta:  1.76 , i:  51
# not done, delta:  1.6 , i:  52
# not done, delta:  1.46 , i:  53
# not done, delta:  1.33 , i:  54
# not done, delta:  1.21 , i:  55
# not done, delta:  1.11 , i:  56
# not done, delta:  1.01 , i:  57
# not done, delta:  0.92 , i:  58
# not done, delta:  0.84 , i:  59
# not done, delta:  0.76 , i:  60
# not done, delta:  0.69 , i:  61
# not done, delta:  0.63 , i:  62
# not done, delta:  0.58 , i:  63
# not done, delta:  0.53 , i:  64
# not done, delta:  0.48 , i:  65
# not done, delta:  0.44 , i:  66
# not done, delta:  0.4 , i:  67
# not done, delta:  0.36 , i:  68
# not done, delta:  0.33 , i:  69
# not done, delta:  0.3 , i:  70
# not done, delta:  0.27 , i:  71
# not done, delta:  0.25 , i:  72
# not done, delta:  0.23 , i:  73
# not done, delta:  0.21 , i:  74
# not done, delta:  0.19 , i:  75
# not done, delta:  0.17 , i:  76
# not done, delta:  0.16 , i:  77
# not done, delta:  0.14 , i:  78
# not done, delta:  0.13 , i:  79
# not done, delta:  0.12 , i:  80
# not done, delta:  0.11 , i:  81
# not done, delta:  0.1 , i:  82
# not done, delta:  0.09 , i:  83
# not done, delta:  0.08 , i:  84
# not done, delta:  0.07 , i:  85
# not done, delta:  0.07 , i:  86
# not done, delta:  0.06 , i:  87
# not done, delta:  0.06 , i:  88
# not done, delta:  0.05 , i:  89
# not done, delta:  0.05 , i:  90
# not done, delta:  0.04 , i:  91
# not done, delta:  0.04 , i:  92
# not done, delta:  0.04 , i:  93
# not done, delta:  0.03 , i:  94
# not done, delta:  0.03 , i:  95
# not done, delta:  0.03 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  0.02 , i:  99
# not done, delta:  109.71 , i:  1
# not done, delta:  102.93 , i:  2
# not done, delta:  96.74 , i:  3
# not done, delta:  91.05 , i:  4
# not done, delta:  85.8 , i:  5
# not done, delta:  80.93 , i:  6
# not done, delta:  76.4 , i:  7
# not done, delta:  72.18 , i:  8
# not done, delta:  68.51 , i:  9
# not done, delta:  65.06 , i:  10
# not done, delta:  61.75 , i:  11
# not done, delta:  58.6 , i:  12
# not done, delta:  55.59 , i:  13
# not done, delta:  52.72 , i:  14
# not done, delta:  49.99 , i:  15
# not done, delta:  47.39 , i:  16
# not done, delta:  44.93 , i:  17
# not done, delta:  42.59 , i:  18
# not done, delta:  40.36 , i:  19
# not done, delta:  38.25 , i:  20
# not done, delta:  36.25 , i:  21
# not done, delta:  34.35 , i:  22
# not done, delta:  32.55 , i:  23
# not done, delta:  30.85 , i:  24
# not done, delta:  29.23 , i:  25
# not done, delta:  27.7 , i:  26
# not done, delta:  26.24 , i:  27
# not done, delta:  24.87 , i:  28
# not done, delta:  23.56 , i:  29
# not done, delta:  22.33 , i:  30
# not done, delta:  21.15 , i:  31
# not done, delta:  20.04 , i:  32
# not done, delta:  18.99 , i:  33
# not done, delta:  17.99 , i:  34
# not done, delta:  17.05 , i:  35
# not done, delta:  16.15 , i:  36
# not done, delta:  15.3 , i:  37
# not done, delta:  14.5 , i:  38
# not done, delta:  13.74 , i:  39
# not done, delta:  13.02 , i:  40
# not done, delta:  12.33 , i:  41
# not done, delta:  11.69 , i:  42
# not done, delta:  11.07 , i:  43
# not done, delta:  10.49 , i:  44
# not done, delta:  9.94 , i:  45
# not done, delta:  9.42 , i:  46
# not done, delta:  8.92 , i:  47
# not done, delta:  8.45 , i:  48
# not done, delta:  8.01 , i:  49
# not done, delta:  7.59 , i:  50
# not done, delta:  7.19 , i:  51
# not done, delta:  6.81 , i:  52
# not done, delta:  6.45 , i:  53
# not done, delta:  6.12 , i:  54
# not done, delta:  5.79 , i:  55
# not done, delta:  5.49 , i:  56
# not done, delta:  5.2 , i:  57
# not done, delta:  4.93 , i:  58
# not done, delta:  4.67 , i:  59
# not done, delta:  4.42 , i:  60
# not done, delta:  4.19 , i:  61
# not done, delta:  3.97 , i:  62
# not done, delta:  3.76 , i:  63
# not done, delta:  3.57 , i:  64
# not done, delta:  3.38 , i:  65
# not done, delta:  3.2 , i:  66
# not done, delta:  3.03 , i:  67
# not done, delta:  2.87 , i:  68
# not done, delta:  2.72 , i:  69
# not done, delta:  2.58 , i:  70
# not done, delta:  2.44 , i:  71
# not done, delta:  2.32 , i:  72
# not done, delta:  2.19 , i:  73
# not done, delta:  2.08 , i:  74
# not done, delta:  1.97 , i:  75
# not done, delta:  1.87 , i:  76
# not done, delta:  1.77 , i:  77
# not done, delta:  1.68 , i:  78
# not done, delta:  1.59 , i:  79
# not done, delta:  1.5 , i:  80
# not done, delta:  1.42 , i:  81
# not done, delta:  1.35 , i:  82
# not done, delta:  1.28 , i:  83
# not done, delta:  1.21 , i:  84
# not done, delta:  1.15 , i:  85
# not done, delta:  1.09 , i:  86
# not done, delta:  1.03 , i:  87
# not done, delta:  0.98 , i:  88
# not done, delta:  0.93 , i:  89
# not done, delta:  0.88 , i:  90
# not done, delta:  0.83 , i:  91
# not done, delta:  0.79 , i:  92
# not done, delta:  0.75 , i:  93
# not done, delta:  0.71 , i:  94
# not done, delta:  0.67 , i:  95
# not done, delta:  0.63 , i:  96
# not done, delta:  0.6 , i:  97
# not done, delta:  0.57 , i:  98
# not done, delta:  0.54 , i:  99
# not done, delta:  185.06 , i:  1
# not done, delta:  167.68 , i:  2
# not done, delta:  153.54 , i:  3
# not done, delta:  139.9 , i:  4
# not done, delta:  127.47 , i:  5
# not done, delta:  116.14 , i:  6
# not done, delta:  105.81 , i:  7
# not done, delta:  96.41 , i:  8
# not done, delta:  87.84 , i:  9
# not done, delta:  80.03 , i:  10
# not done, delta:  72.92 , i:  11
# not done, delta:  66.44 , i:  12
# not done, delta:  60.53 , i:  13
# not done, delta:  55.15 , i:  14
# not done, delta:  50.25 , i:  15
# not done, delta:  45.79 , i:  16
# not done, delta:  41.72 , i:  17
# not done, delta:  38.01 , i:  18
# not done, delta:  34.63 , i:  19
# not done, delta:  31.55 , i:  20
# not done, delta:  28.75 , i:  21
# not done, delta:  26.19 , i:  22
# not done, delta:  23.86 , i:  23
# not done, delta:  21.74 , i:  24
# not done, delta:  19.81 , i:  25
# not done, delta:  18.05 , i:  26
# not done, delta:  16.45 , i:  27
# not done, delta:  14.98 , i:  28
# not done, delta:  13.65 , i:  29
# not done, delta:  12.44 , i:  30
# not done, delta:  11.33 , i:  31
# not done, delta:  10.33 , i:  32
# not done, delta:  9.41 , i:  33
# not done, delta:  8.57 , i:  34
# not done, delta:  7.81 , i:  35
# not done, delta:  7.12 , i:  36
# not done, delta:  6.48 , i:  37
# not done, delta:  5.91 , i:  38
# not done, delta:  5.38 , i:  39
# not done, delta:  4.9 , i:  40
# not done, delta:  4.47 , i:  41
# not done, delta:  4.07 , i:  42
# not done, delta:  3.71 , i:  43
# not done, delta:  3.38 , i:  44
# not done, delta:  3.08 , i:  45
# not done, delta:  2.81 , i:  46
# not done, delta:  2.56 , i:  47
# not done, delta:  2.33 , i:  48
# not done, delta:  2.12 , i:  49
# not done, delta:  1.93 , i:  50
# not done, delta:  1.76 , i:  51
# not done, delta:  1.6 , i:  52
# not done, delta:  1.46 , i:  53
# not done, delta:  1.33 , i:  54
# not done, delta:  1.21 , i:  55
# not done, delta:  1.11 , i:  56
# not done, delta:  1.01 , i:  57
# not done, delta:  0.92 , i:  58
# not done, delta:  0.84 , i:  59
# not done, delta:  0.76 , i:  60
# not done, delta:  0.69 , i:  61
# not done, delta:  0.63 , i:  62
# not done, delta:  0.58 , i:  63
# not done, delta:  0.53 , i:  64
# not done, delta:  0.48 , i:  65
# not done, delta:  0.44 , i:  66
# not done, delta:  0.4 , i:  67
# not done, delta:  0.36 , i:  68
# not done, delta:  0.33 , i:  69
# not done, delta:  0.3 , i:  70
# not done, delta:  0.27 , i:  71
# not done, delta:  0.25 , i:  72
# not done, delta:  0.23 , i:  73
# not done, delta:  0.21 , i:  74
# not done, delta:  0.19 , i:  75
# not done, delta:  0.17 , i:  76
# not done, delta:  0.16 , i:  77
# not done, delta:  0.14 , i:  78
# not done, delta:  0.13 , i:  79
# not done, delta:  0.12 , i:  80
# not done, delta:  0.11 , i:  81
# not done, delta:  0.1 , i:  82
# not done, delta:  0.09 , i:  83
# not done, delta:  0.08 , i:  84
# not done, delta:  0.07 , i:  85
# not done, delta:  0.07 , i:  86
# not done, delta:  0.06 , i:  87
# not done, delta:  0.06 , i:  88
# not done, delta:  0.05 , i:  89
# not done, delta:  0.05 , i:  90
# not done, delta:  0.04 , i:  91
# not done, delta:  0.04 , i:  92
# not done, delta:  0.04 , i:  93
# not done, delta:  0.03 , i:  94
# not done, delta:  0.03 , i:  95
# not done, delta:  0.03 , i:  96
# not done, delta:  0.02 , i:  97
# not done, delta:  0.02 , i:  98
# not done, delta:  0.02 , i:  99
# not done, delta:  109.71 , i:  1
# not done, delta:  102.93 , i:  2
# not done, delta:  96.74 , i:  3
# not done, delta:  91.05 , i:  4
# not done, delta:  85.8 , i:  5
# not done, delta:  80.93 , i:  6
# not done, delta:  76.4 , i:  7
# not done, delta:  72.18 , i:  8
# not done, delta:  68.51 , i:  9
# not done, delta:  65.06 , i:  10
# not done, delta:  61.75 , i:  11
# not done, delta:  58.6 , i:  12
# not done, delta:  55.59 , i:  13
# not done, delta:  52.72 , i:  14
# not done, delta:  49.99 , i:  15
# not done, delta:  47.39 , i:  16
# not done, delta:  44.93 , i:  17
# not done, delta:  42.59 , i:  18
# not done, delta:  40.36 , i:  19
# not done, delta:  38.25 , i:  20
# not done, delta:  36.25 , i:  21
# not done, delta:  34.35 , i:  22
# not done, delta:  32.55 , i:  23
# not done, delta:  30.85 , i:  24
# not done, delta:  29.23 , i:  25
# not done, delta:  27.7 , i:  26
# not done, delta:  26.24 , i:  27
# not done, delta:  24.87 , i:  28
# not done, delta:  23.56 , i:  29
# not done, delta:  22.33 , i:  30
# not done, delta:  21.15 , i:  31
# not done, delta:  20.04 , i:  32
# not done, delta:  18.99 , i:  33
# not done, delta:  17.99 , i:  34
# not done, delta:  17.05 , i:  35
# not done, delta:  16.15 , i:  36
# not done, delta:  15.3 , i:  37
# not done, delta:  14.5 , i:  38
# not done, delta:  13.74 , i:  39
# not done, delta:  13.02 , i:  40
# not done, delta:  12.33 , i:  41
# not done, delta:  11.69 , i:  42
# not done, delta:  11.07 , i:  43
# not done, delta:  10.49 , i:  44
# not done, delta:  9.94 , i:  45
# not done, delta:  9.42 , i:  46
# not done, delta:  8.92 , i:  47
# not done, delta:  8.45 , i:  48
# not done, delta:  8.01 , i:  49
# not done, delta:  7.59 , i:  50
# not done, delta:  7.19 , i:  51
# not done, delta:  6.81 , i:  52
# not done, delta:  6.45 , i:  53
# not done, delta:  6.12 , i:  54
# not done, delta:  5.79 , i:  55
# not done, delta:  5.49 , i:  56
# not done, delta:  5.2 , i:  57
# not done, delta:  4.93 , i:  58
# not done, delta:  4.67 , i:  59
# not done, delta:  4.42 , i:  60
# not done, delta:  4.19 , i:  61
# not done, delta:  3.97 , i:  62
# not done, delta:  3.76 , i:  63
# not done, delta:  3.57 , i:  64
# not done, delta:  3.38 , i:  65
# not done, delta:  3.2 , i:  66
# not done, delta:  3.03 , i:  67
# not done, delta:  2.87 , i:  68
# not done, delta:  2.72 , i:  69
# not done, delta:  2.58 , i:  70
# not done, delta:  2.44 , i:  71
# not done, delta:  2.32 , i:  72
# not done, delta:  2.19 , i:  73
# not done, delta:  2.08 , i:  74
# not done, delta:  1.97 , i:  75
# not done, delta:  1.87 , i:  76
# not done, delta:  1.77 , i:  77
# not done, delta:  1.68 , i:  78
# not done, delta:  1.59 , i:  79
# not done, delta:  1.5 , i:  80
# not done, delta:  1.42 , i:  81
# not done, delta:  1.35 , i:  82
# not done, delta:  1.28 , i:  83
# not done, delta:  1.21 , i:  84
# not done, delta:  1.15 , i:  85
# not done, delta:  1.09 , i:  86
# not done, delta:  1.03 , i:  87
# not done, delta:  0.98 , i:  88
# not done, delta:  0.93 , i:  89
# not done, delta:  0.88 , i:  90
# not done, delta:  0.83 , i:  91
# not done, delta:  0.79 , i:  92
# not done, delta:  0.75 , i:  93
# not done, delta:  0.71 , i:  94
# not done, delta:  0.67 , i:  95
# not done, delta:  0.63 , i:  96
# not done, delta:  0.6 , i:  97
# not done, delta:  0.57 , i:  98
# not done, delta:  0.54 , i:  99
# Policy:  {'maintain': 0.1, 'change': 0.9}
# not done, delta:  22.38 , i:  1
# not done, delta:  20.3 , i:  2
# not done, delta:  18.59 , i:  3
# not done, delta:  16.93 , i:  4
# not done, delta:  15.43 , i:  5
# not done, delta:  14.06 , i:  6
# not done, delta:  12.81 , i:  7
# not done, delta:  11.67 , i:  8
# not done, delta:  10.63 , i:  9
# not done, delta:  9.69 , i:  10
# not done, delta:  8.83 , i:  11
# not done, delta:  8.04 , i:  12
# not done, delta:  7.33 , i:  13
# not done, delta:  6.68 , i:  14
# not done, delta:  6.08 , i:  15
# not done, delta:  5.54 , i:  16
# not done, delta:  5.05 , i:  17
# not done, delta:  4.6 , i:  18
# not done, delta:  4.19 , i:  19
# not done, delta:  3.82 , i:  20
# not done, delta:  3.48 , i:  21
# not done, delta:  3.17 , i:  22
# not done, delta:  2.89 , i:  23
# not done, delta:  2.63 , i:  24
# not done, delta:  2.4 , i:  25
# not done, delta:  2.18 , i:  26
# not done, delta:  1.99 , i:  27
# not done, delta:  1.81 , i:  28
# not done, delta:  1.65 , i:  29
# not done, delta:  1.51 , i:  30
# not done, delta:  1.37 , i:  31
# not done, delta:  1.25 , i:  32
# not done, delta:  1.14 , i:  33
# not done, delta:  1.04 , i:  34
# not done, delta:  0.95 , i:  35
# not done, delta:  0.86 , i:  36
# not done, delta:  0.78 , i:  37
# not done, delta:  0.72 , i:  38
# not done, delta:  0.65 , i:  39
# not done, delta:  0.59 , i:  40
# not done, delta:  0.54 , i:  41
# not done, delta:  0.49 , i:  42
# not done, delta:  0.45 , i:  43
# not done, delta:  0.41 , i:  44
# not done, delta:  0.37 , i:  45
# not done, delta:  0.34 , i:  46
# not done, delta:  0.31 , i:  47
# not done, delta:  0.28 , i:  48
# not done, delta:  0.26 , i:  49
# not done, delta:  0.23 , i:  50
# not done, delta:  0.21 , i:  51
# not done, delta:  0.19 , i:  52
# not done, delta:  0.18 , i:  53
# not done, delta:  0.16 , i:  54
# not done, delta:  0.15 , i:  55
# not done, delta:  0.13 , i:  56
# not done, delta:  0.12 , i:  57
# not done, delta:  0.11 , i:  58
# not done, delta:  0.1 , i:  59
# not done, delta:  0.09 , i:  60
# not done, delta:  0.08 , i:  61
# not done, delta:  0.08 , i:  62
# not done, delta:  0.07 , i:  63
# not done, delta:  0.06 , i:  64
# not done, delta:  0.06 , i:  65
# not done, delta:  0.05 , i:  66
# not done, delta:  0.05 , i:  67
# not done, delta:  0.04 , i:  68
# not done, delta:  0.04 , i:  69
# not done, delta:  0.04 , i:  70
# not done, delta:  0.03 , i:  71
# not done, delta:  0.03 , i:  72
# not done, delta:  0.03 , i:  73
# not done, delta:  0.03 , i:  74
# not done, delta:  0.02 , i:  75
# not done, delta:  0.02 , i:  76
# not done, delta:  0.02 , i:  77
# not done, delta:  0.02 , i:  78
# not done, delta:  0.02 , i:  79
# Policy:  {'maintain': 0.1, 'change': 0.9}
